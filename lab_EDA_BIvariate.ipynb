# %%
# import libraries
import pandas as pd
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# %matplotlib inline

# %%
# read data
data = pd.read_csv(R'../Homework/amz_uk_price_prediction_dataset.csv')
data.head()
# Out:
#    uid        asin                                              title  stars  \
# 0    1  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 1    2  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...    4.7
# 2    3  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 3    4  B09B8T5VGV  Echo Dot with clock (5th generation, 2022 rele...    4.7
# 4    5  B09WX6QD65  Introducing Echo Pop | Full sound compact Wi-F...    4.6
#
#    reviews  price  isBestSeller  boughtInLastMonth        category
# 0    15308  21.99         False                  0  Hi-Fi Speakers
# 1    98099  23.99          True                  0  Hi-Fi Speakers
# 2    15308  21.99         False                  0  Hi-Fi Speakers
# 3     7205  31.99         False                  0  Hi-Fi Speakers
# 4     1881  17.99         False                  0  Hi-Fi Speakers

# %% [markdown]
# Crosstab Analysis:
#
# Create a crosstab between the product category and the isBestSeller status.
#
# Are there categories where being a best-seller is more prevalent?
#
# Hint: one option is to calculate the proportion of best-sellers for each category and then sort the categories based on this proportion in descending order.

# %%
# calculate the is bestseler column true proportion

# %%
proportion_table = data['category'].value_counts(normalize=True)
proportion_table
# Out:
# category
# Sports & Outdoors                         0.342219
# Beauty                                    0.007903
# Handmade Clothing, Shoes & Accessories    0.007869
# Bath & Body                               0.007813
# Birthday Gifts                            0.007766
#                                             ...
# Alexa Built-In Devices                    0.000044
# Motorbike Chassis                         0.000044
# Plugs                                     0.000044
# Smart Home Security & Lighting            0.000043
# Smart Speakers                            0.000022
# Name: proportion, Length: 296, dtype: float64

# %%
frequency_table = data['category'].value_counts().head(10)
frequency_table
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Manicure & Pedicure Products               18940
# Skin Care                                  18769
# Make-up                                    18756
# Hair Care                                  18735
# Fragrances                                 18564
# Name: count, dtype: int64

# %%
data1 = data[data['category'].isin(frequency_table.index)]

# %%
crosstab_result = pd.crosstab(data1['category'], data1['isBestSeller'])

crosstab_result
# Out:
# isBestSeller                             False  True
# category
# Bath & Body                              19059     33
# Beauty                                   19010    302
# Birthday Gifts                           18943     35
# Fragrances                               18550     14
# Hair Care                                18665     70
# Handmade Clothing, Shoes & Accessories   19215     14
# Make-up                                  18715     41
# Manicure & Pedicure Products             18882     58
# Skin Care                                18711     58
# Sports & Outdoors                       835935    330

# %% [markdown]
# Statistical Tests:
#
# Conduct a Chi-square test to determine if the best-seller distribution is independent of the product category.

# %%
from scipy.stats import chi2_contingency

# Chi-square test for 'MSZoning' and 'SaleCondition'
chi2_statistic, chi2_p_value, _, _ = chi2_contingency(crosstab_result)

chi2_statistic, chi2_p_value
# Out:
# (5061.427234973771, 0.0)

# %% [markdown]
# Compute Cramér's V to understand the strength of association between best-seller status and category.

# %%
from scipy.stats.contingency import association

# Computing the association between variables in 'crosstab_result' using the "cramer" method
association(crosstab_result, method="cramer")
# Out:
# 0.07090868100911123

# %% [markdown]
# Visualizations:
#
# Visualize the relationship between product categories and the best-seller status using a stacked bar chart.

# %%
crosstab_result.plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='category'>

# %%
sns.heatmap(crosstab_result, annot=True, cmap="YlGnBu", fmt="d")
# Out:
# <Axes: xlabel='isBestSeller', ylabel='category'>

# %%
sns.countplot(data=data1, x='category', hue='isBestSeller')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 sns.countplot(data=data1, x='category', hue='isBestSeller')
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %% [markdown]
# Part 2: Exploring Product Prices and Ratings Across Categories and Brands
# Objective: Investigate how different product categories influence product prices.
#
# Preliminary Step: Remove outliers in product prices.
#
# For this purpose, we can use the IQR (Interquartile Range) method. Products priced below the first quartile minus 1.5 times the IQR or above the third quartile plus 1.5 times the IQR will be considered outliers and removed from the dataset. The next steps will be done with the dataframe without outliers.
#
# Hint: you can check the last Check For Understanding at the end of the lesson EDA Bivariate Analysis for a hint on how to do this.

# %%
def tukeys_test_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    
    # Define bounds for the outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify the outliers
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    
    return outliers

tukeys_test_outliers(data['price'])
# Out:
# 10         139.00
# 19         164.99
# 25         149.99
# 28         289.00
# 31         199.99
#             ...
# 2443619    166.99
# 2443627    152.58
# 2443638    108.77
# 2443641    166.99
# 2443643    158.99
# Name: price, Length: 327688, dtype: float64

# %%
data
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
# price outliers

data_price_outlier = data[data['price'].isin (tukeys_test_outliers(data['price']))]
data_price_outlier
# Out:
#              uid        asin  \
# 10            11  B08VDNCZT9
# 19            20  B07NQCKJSH
# 25            26  B0BLS36M5R
# 28            29  B096G3R7C3
# 31            32  B08MQRDDYB
# ...          ...         ...
# 2443619  2828560  B07JLZB7YY
# 2443627  2828568  B005QN452A
# 2443638  2828579  B084R261ML
# 2443641  2828582  B07JM93SCC
# 2443643  2828586  B07JM5VQFX
#
#                                                      title  stars  reviews  \
# 10       JBL Charge 5 - Portable Bluetooth Speaker with...    4.8    11920
# 19       Echo Studio | Our best-sounding Wi-Fi and Blue...    4.5    14222
# 25       All-new Echo Show 8 | 3rd generation (2023 rel...    0.0        0
# 28       JBL PartyBox110 Portable Indoor and Outdoor Pa...    4.8      153
# 31       Echo Show 15 | Full HD 15.6" smart display wit...    4.4     2616
# ...                                                    ...    ...      ...
# 2443619  Motorcycle Clothing Suit - Motorbike Suit With...    0.0        0
# ...

# %%
#remove price outliers
data_without_outlier = data[~data['price'].isin(tukeys_test_outliers(data['price']))]
data_without_outlier
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %% [markdown]
# Violin Plots:
#
# Use a violin plot to visualize the distribution of price across different product categories. Filter out the top 20 categories based on count for better visualization.
# Which product category tends to have the highest median price? Don't filter here by top categories.

# %%
data_without_outlier['category'].value_counts().head(20)
# Out:
# category
# Sports & Outdoors                         694092
# Beauty                                     19233
# Bath & Body                                19050
# Manicure & Pedicure Products               18904
# Handmade Clothing, Shoes & Accessories     18811
# Make-up                                    18718
# Skin Care                                  18686
# Hair Care                                  18625
# Birthday Gifts                             18398
# Handmade Gifts                             17948
# Handmade Home Décor                        17675
# Luggage and travel gear                    17557
# Women                                      17476
# Fragrances                                 17431
# Handmade Kitchen & Dining                  17346
# Handmade Artwork                           17269
# Handmade Home & Kitchen Products           17175
# Handmade Jewellery                         17135
# Men                                        16596
# ...

# %%
Top_20_category = data_without_outlier['category'].value_counts().head(20)
Top_20_category = pd.DataFrame(Top_20_category)
Top_20_category
# Out:
#                                          count
# category
# Sports & Outdoors                       694092
# Beauty                                   19233
# Bath & Body                              19050
# Manicure & Pedicure Products             18904
# Handmade Clothing, Shoes & Accessories   18811
# Make-up                                  18718
# Skin Care                                18686
# Hair Care                                18625
# Birthday Gifts                           18398
# Handmade Gifts                           17948
# Handmade Home Décor                      17675
# Luggage and travel gear                  17557
# Women                                    17476
# Fragrances                               17431
# Handmade Kitchen & Dining                17346
# Handmade Artwork                         17269
# Handmade Home & Kitchen Products         17175
# Handmade Jewellery                       17135
# Men                                      16596
# ...

# %%
#filter data for top 20 category
data_top_20_category = data_without_outlier[data_without_outlier['category'].isin(Top_20_category.index)]
data_top_20_category
# Out:
#              uid        asin  \
# 19513      21072  B09477KHQ3
# 19514      21073  B0BSRFQYG8
# 19515      21074  B09N9GVHV9
# 19516      21075  B0BRYGV7PQ
# 19517      21076  B0B1JHB28R
# ...          ...         ...
# 2429088  2806950  B0045I6SHW
# 2429089  2806951  B0045I6NZY
# 2429090  2806952  B003BLON3A
# 2437153  2818782  B091HG57TP
# 2437154  2818786  B09F8TFQDM
#
#                                                      title  stars  reviews  \
# 19513    Personalised Birthday Print Gift "THE YEAR YOU...    4.5      763
# 19514    Wax Melts 4 Bars | Build Your Own Box (Choose ...    3.9      117
# 19515    Personalised Birthday Print Gift "ON THE DAY/Y...    4.6     1155
# 19516    Fresh Wax Melts - Laundry Type Wax Melts - Str...    4.5       56
# 19517    Manta Makes Work Leaving Gifts | I Used to Wor...    4.7      261
# ...                                                    ...    ...      ...
# 2429088    Cannondale Men's Bibshort Dart Team Bike Shorts    0.0        0
# ...

# %%
# Plotting a violin plot to visualize the distribution of 'price' for each category, using the "coolwarm" color palette

plt.figure(figsize=(20, 8))
sns.violinplot(data=data_top_20_category, x='category', y='price', palette="coolwarm")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Bar Charts:
#
# Create a bar chart comparing the average price of products for the top 10 product categories (based on count).
# Which product category commands the highest average price? Don't filter here by top categories.

# %%
Top_10_category = data_without_outlier['category'].value_counts().head(10)
Top_10_category = pd.DataFrame(Top_10_category)
Top_10_category
# Out:
#                                          count
# category
# Sports & Outdoors                       694092
# Beauty                                   19233
# Bath & Body                              19050
# Manicure & Pedicure Products             18904
# Handmade Clothing, Shoes & Accessories   18811
# Make-up                                  18718
# Skin Care                                18686
# Hair Care                                18625
# Birthday Gifts                           18398
# Handmade Gifts                           17948

# %%
top10 = data_without_outlier[data_without_outlier['category'].isin(Top_10_category['category'])]
top10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 top10 = data_without_outlier[data_without_outlier['category'].isin(Top_10_category['category'])]
#       2 top10
#
# NameError: name 'data_without_outlier' is not defined

# %%
# calculate the mean price for each category
mean_price_per_category = top10.groupby('category')['price'].mean().sort_values(ascending=False)
mean_price_per_category
# Out:
# category
# Sports & Outdoors                         25.172065
# Birthday Gifts                            18.600195
# Handmade Gifts                            17.395112
# Skin Care                                 15.654722
# Bath & Body                               14.678683
# Hair Care                                 13.461408
# Handmade Clothing, Shoes & Accessories    12.958639
# Beauty                                    12.523480
# Make-up                                   10.612918
# Manicure & Pedicure Products              10.231825
# Name: price, dtype: float64

# %%
#Create a bar chart comparing the average price of products for the top 10 product categories (based on count)
plt.figure(figsize=(15, 8))
sns.barplot(data=top10, x='category', y='price', estimator=np.mean, ci=None)
plt.xticks(rotation=90)
plt.title("Average Price of Products for the Top 10 Product Categories")
plt.show()
# Out:
# /var/folders/l5/p6r57rz54js0nf3r65vn2xy80000gn/T/ipykernel_63419/2313832418.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=top10, x='category', y='price', estimator=np.mean, ci=None)

# %%
# calculate the mean price for each category
mean_price_per_category = top10.groupby('category')['price'].mean()
mean_price_per_category = pd.DataFrame(mean_price_per_category)
mean_price_per_category

#Create a bar chart comparing the average price of products for the top 10 product categories (based on count)
plt.figure(figsize=(15, 8))
sns.barplot(data=mean_price_per_category, x=mean_price_per_category.index, y='price', palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Average Price of Products for the Top 10 Product Categories")
plt.show()

# %% [markdown]
# Box Plots:
#
# Visualize the distribution of product ratings based on their category using side-by-side box plots. Filter out the top 10 categories based on count for better visualization.
# Which category tends to receive the highest median rating from customers? Don't filter here by top categories.

# %%
data_without_outlier
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
top10
# Out:
#              uid        asin  \
# 82163      89483  B07DLGZ828
# 82164      89484  B09HGZHXJT
# 82167      89487  B08LD4VXGL
# 82168      89488  B07QDMLMJH
# 82169      89489  B09TQMCNY7
# ...          ...         ...
# 2429088  2806950  B0045I6SHW
# 2429089  2806951  B0045I6NZY
# 2429090  2806952  B003BLON3A
# 2437153  2818782  B091HG57TP
# 2437154  2818786  B09F8TFQDM
#
#                                                      title  stars  reviews  \
# 82163    Neutrade GoPro 3M Sticky Pads Double Sided Adh...    4.2     3116
# 82164    WOLFANG Action Camera 4K 20MP GA100, Waterproo...    4.2     2594
# 82167    FitStill 60M/196FT Waterproof Case for Go Pro ...    4.5     9879
# 82168    Nextbase Powered Mount Variations For Cameras ...    4.7     1223
# 82169    WOLFANG Action Camera GA100 with 64GB microSDX...    4.2       55
# ...                                                    ...    ...      ...
# 2429088    Cannondale Men's Bibshort Dart Team Bike Shorts    0.0        0
# ...

# %%
# Visualize the distribution of product ratings based on their category using side-by-side box plots.
plt.figure(figsize=(15, 8))
sns.boxplot(data=top10, x='category', y='stars')
plt.xticks(rotation=90)
plt.title("Distribution of Product Ratings Based on Category")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 # Visualize the distribution of product ratings based on their category using side-by-side box plots.
#       2 plt.figure(figsize=(15, 8))
# ----> 3 sns.boxplot(data=top10, x='category', y='stars')
#       4 plt.xticks(rotation=90)
#       5 plt.title("Distribution of Product Ratings Based on Category")
#
# NameError: name 'top10' is not defined

# %% [markdown]
# Part 3: Investigating the Interplay Between Product Prices and Ratings
# Objective: Analyze how product ratings (stars) correlate with product prices.
#
# Correlation Coefficients:
#
# Calculate the correlation coefficient between price and stars.
# Is there a significant correlation between product price and its rating?

# %%
correlation = data_without_outlier['price'].corr(data_without_outlier['reviews'])
correlation
# Out:
# -0.008497583007235946

# %% [markdown]
# Visualizations:
#
# Use a scatter plot to visualize the relationship between product rating and price. What patterns can you observe?
#
# Use a correlation heatmap to visualize correlations between all numerical variables.
#
# Examine if product prices typically follow a normal distribution using a QQ plot.

# %%
# use scatter plot to visualize the relationship between 'price' and 'stars'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data_without_outlier, x='price', y='stars')
plt.title("Relationship between Price and Stars")
plt.show()

# %%
# use heatmap to visualize the correlation between 'price' and 'stars'
plt.figure(figsize=(10, 6))
sns.heatmap(data_without_outlier[['price', 'stars']].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation between Price and Stars")
plt.show()
